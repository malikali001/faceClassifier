# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
# !pip install opencv-python
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell\.pyenv\pyenv-win\versions\3.12.0\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\.pyenv\pyenv-win\versions\3.12.0\lib\site-packages (from opencv-python) (2.1.1)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/IMG_20180805_214752.jpg')
img.shape
# Out:
# (2560, 1920, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (2560, 1920)

# %%
gray
# Out:
# array([[176, 169, 167, ..., 192, 192, 189],
#        [173, 168, 168, ..., 187, 190, 193],
#        [178, 176, 181, ..., 184, 190, 198],
#        ...,
#        [159, 160, 167, ..., 184, 186, 186],
#        [156, 157, 160, ..., 183, 182, 181],
#        [157, 156, 151, ..., 183, 178, 178]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 531,  756, 1033, 1033]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (np.int32(531), np.int32(756), np.int32(1033), np.int32(1033))

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1033, 1033, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
# !pip install PyWavelets
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H
# Out:
# Requirement already satisfied: PyWavelets in c:\users\dell\.pyenv\pyenv-win\versions\3.12.0\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\dell\.pyenv\pyenv-win\versions\3.12.0\lib\site-packages (from PyWavelets) (2.1.1)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Failed to load image: {image_path}")
        return None
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/IMG_20180805_214752.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/IMG_20180805_214752.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/IMG_20180805_214752.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/13619922_1554595171515212_8813561321870837864_n.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/alexandra-daddario',
#  './dataset/cropped',
#  './dataset/eva-green',
#  './dataset/husnain',
#  './dataset/ronaldo']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/alexandra-daddario
# Failed to load image: ./dataset/alexandra-daddario\Actress Alexandra Daddario — Stock ... (1).jpg
# Failed to load image: ./dataset/alexandra-daddario\Actress Alexandra Daddario — Stock ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario - AlloCiné.jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario Is Pregnant—and ... (1).jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario Is Pregnant—and ... (2).jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario Is Pregnant—and ... (3).jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario Is Pregnant—and ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario on Red Carpet – “The ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario је додао_ла нову ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario – Emmy Awards 2022 ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario – Movies, Bio and ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario – The Next One Is ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Alexandra Daddario — The Movie ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Good morning! 😻🖤 #alexandradaddario.jpg
# Failed to load image: ./dataset/alexandra-daddario\How Alexandra Daddario & Fiancé Andrew ... (1).jpg
# Failed to load image: ./dataset/alexandra-daddario\How Alexandra Daddario & Fiancé Andrew ....jpg
# Failed to load image: ./dataset/alexandra-daddario\Met gala ❤️ - Alexandra Daddario _ Facebook.jpg
# Failed to load image: ./dataset/alexandra-daddario\New Orleans 🎉.jpg
# Failed to load image: ./dataset/alexandra-daddario\𝘼𝙡𝙚𝙭𝙖𝙣𝙙𝙧𝙖 𝘿𝙖𝙙𝙙𝙖𝙧𝙞𝙤 Photography Book ....jpg
# Failed to load image: ./dataset/cropped\alexandra-daddario
# Generating cropped images in folder:  ./dataset/cropped/eva-green
# Failed to load image: ./dataset/eva-green\Actress Eva Green — Stock Editorial ... (1).jpg
# Failed to load image: ./dataset/eva-green\Actress Eva Green — Stock Editorial ... (2).jpg
# Failed to load image: ./dataset/eva-green\Actress Eva Green — Stock Editorial ... (3).jpg
# Failed to load image: ./dataset/eva-green\Actress Eva Green — Stock Editorial ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green - Profile Images — The Movie ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green - Starporträt, News, Bilder ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green Low-Midriff Exposé _ Stable ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green _ famille, carrière, couple ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green _ invitée spéciale ! - C à ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green – Bvlgari Gala Dinner in Rome ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green — The Movie Database (TMDB) (1).jpg
# Failed to load image: ./dataset/eva-green\Eva Green — The Movie Database (TMDB).jpg
# Failed to load image: ./dataset/eva-green\Eva Green 🖤 Cannes 2024 · Ciné Watch ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green's Best Looks – Fashion ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green_ New L'Oréal Professionnel ....jpg
# Failed to load image: ./dataset/eva-green\Eva Green_ «J'aime les rôles extrêmes ....jpg
# Failed to load image: ./dataset/eva-green\EvaGreen® Dye, 20X in Water - Biotium.jpg
# Failed to load image: ./dataset/eva-green\Evil', 'peasants' and 'vomit' – Eva ....jpg
# Failed to load image: ./dataset/eva-green\Product Questions – Eva Green Purple ....jpg
# Failed to load image: ./dataset/eva-green\The Three Musketeers_ D'Artagnan – _Eva ....jpg
# Failed to load image: ./dataset/eva-green\WCW_ Eva Green – Frock Flicks.jpg
# Failed to load image: ./dataset/eva-green\𝒏 𝐞 𝐰, 𝒎𝒂𝐠𝒂𝐳𝒊𝒏𝐞 ; Eva Green... - Eva ....jpg
# Generating cropped images in folder:  ./dataset/cropped/husnain
# Generating cropped images in folder:  ./dataset/cropped/ronaldo
# Failed to load image: ./dataset/ronaldo\900 goals 🤯 #cristianoronaldo #cr7 #goat.jpg
# Failed to load image: ./dataset/ronaldo\Biography – Cristiano Ronaldo.jpg
# Failed to load image: ./dataset/ronaldo\Cristiano Ronaldo EA SPORTS FC™ 25 ....jpg
# Failed to load image: ./dataset/ronaldo\Cristiano Ronaldo Fragrances – Eden ....jpg
# Failed to load image: ./dataset/ronaldo\Cristiano Ronaldo — Qaraqalpaqsha ....jpg
# Failed to load image: ./dataset/ronaldo\Cristiano Ronaldo ○King Of Dribbling ....jpg
# Failed to load image: ./dataset/ronaldo\Fabrizio Romano on X_ _❤️🇵🇹 Cristiano ....jpg
# Failed to load image: ./dataset/ronaldo\Siuuuuu 🔥 Cristiano Ronaldo ....jpg
# Failed to load image: ./dataset/ronaldo\Young Ronaldo was UNREAL 🔥😍 - YouTube.jpg
# Failed to load image: ./dataset/ronaldo\€550k per day' - Cristiano Ronaldo on ....jpg
# Failed to load image: ./dataset/ronaldo\🇵🇹 Cristiano Ronaldo for Portugal_ ▶️ ....jpg

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'alexandra-daddario': ['./dataset/cropped/alexandra-daddario\\alexandra-daddario1.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario10.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario100.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario101.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario102.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario103.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario104.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario105.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario106.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario107.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario108.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario109.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario11.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario110.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario111.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario112.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario113.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario114.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario115.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario116.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario117.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario118.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario119.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario12.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario120.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario121.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario122.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario123.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario124.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario125.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario126.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario127.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario128.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario129.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario13.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario130.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario131.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario132.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario133.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario134.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario135.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario136.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario137.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario138.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario139.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario140.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario141.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario142.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario143.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario144.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario145.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario146.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario147.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario148.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario149.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario150.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario152.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario153.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario155.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario156.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario157.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario158.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario159.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario16.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario160.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario161.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario162.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario163.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario164.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario165.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario166.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario167.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario168.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario169.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario17.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario170.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario171.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario172.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario173.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario174.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario175.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario177.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario178.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario179.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario18.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario180.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario19.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario2.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario20.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario21.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario22.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario23.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario24.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario25.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario26.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario27.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario28.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario29.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario3.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario30.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario31.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario32.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario33.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario34.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario35.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario36.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario37.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario38.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario39.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario4.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario40.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario41.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario42.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario43.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario44.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario45.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario46.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario47.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario48.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario49.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario5.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario50.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario52.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario53.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario54.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario55.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario56.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario57.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario58.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario59.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario6.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario60.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario61.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario62.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario63.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario65.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario66.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario67.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario68.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario69.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario7.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario70.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario71.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario72.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario74.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario75.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario76.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario77.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario78.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario79.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario8.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario80.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario81.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario82.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario83.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario84.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario85.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario86.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario87.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario88.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario89.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario9.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario90.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario91.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario92.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario93.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario94.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario95.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario96.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario97.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario98.png',
#   './dataset/cropped/alexandra-daddario\\alexandra-daddario99.png'],
#  'eva-green': ['./dataset/cropped/eva-green\\eva-green1.png',
#   './dataset/cropped/eva-green\\eva-green10.png',
#   './dataset/cropped/eva-green\\eva-green100.png',
#   './dataset/cropped/eva-green\\eva-green101.png',
#   './dataset/cropped/eva-green\\eva-green102.png',
#   './dataset/cropped/eva-green\\eva-green103.png',
#   './dataset/cropped/eva-green\\eva-green104.png',
#   './dataset/cropped/eva-green\\eva-green105.png',
#   './dataset/cropped/eva-green\\eva-green106.png',
#   './dataset/cropped/eva-green\\eva-green107.png',
#   './dataset/cropped/eva-green\\eva-green108.png',
#   './dataset/cropped/eva-green\\eva-green11.png',
#   './dataset/cropped/eva-green\\eva-green12.png',
#   './dataset/cropped/eva-green\\eva-green13.png',
#   './dataset/cropped/eva-green\\eva-green14.png',
#   './dataset/cropped/eva-green\\eva-green15.png',
#   './dataset/cropped/eva-green\\eva-green16.png',
#   './dataset/cropped/eva-green\\eva-green17.png',
#   './dataset/cropped/eva-green\\eva-green18.png',
#   './dataset/cropped/eva-green\\eva-green19.png',
#   './dataset/cropped/eva-green\\eva-green2.png',
#   './dataset/cropped/eva-green\\eva-green20.png',
#   './dataset/cropped/eva-green\\eva-green21.png',
#   './dataset/cropped/eva-green\\eva-green22.png',
#   './dataset/cropped/eva-green\\eva-green23.png',
#   './dataset/cropped/eva-green\\eva-green24.png',
#   './dataset/cropped/eva-green\\eva-green25.png',
#   './dataset/cropped/eva-green\\eva-green26.png',
#   './dataset/cropped/eva-green\\eva-green27.png',
#   './dataset/cropped/eva-green\\eva-green28.png',
#   './dataset/cropped/eva-green\\eva-green29.png',
#   './dataset/cropped/eva-green\\eva-green3.png',
#   './dataset/cropped/eva-green\\eva-green30.png',
#   './dataset/cropped/eva-green\\eva-green31.png',
#   './dataset/cropped/eva-green\\eva-green32.png',
#   './dataset/cropped/eva-green\\eva-green33.png',
#   './dataset/cropped/eva-green\\eva-green34.png',
#   './dataset/cropped/eva-green\\eva-green35.png',
#   './dataset/cropped/eva-green\\eva-green36.png',
#   './dataset/cropped/eva-green\\eva-green37.png',
#   './dataset/cropped/eva-green\\eva-green38.png',
#   './dataset/cropped/eva-green\\eva-green39.png',
#   './dataset/cropped/eva-green\\eva-green4.png',
#   './dataset/cropped/eva-green\\eva-green40.png',
#   './dataset/cropped/eva-green\\eva-green41.png',
#   './dataset/cropped/eva-green\\eva-green42.png',
#   './dataset/cropped/eva-green\\eva-green43.png',
#   './dataset/cropped/eva-green\\eva-green44.png',
#   './dataset/cropped/eva-green\\eva-green45.png',
#   './dataset/cropped/eva-green\\eva-green46.png',
#   './dataset/cropped/eva-green\\eva-green47.png',
#   './dataset/cropped/eva-green\\eva-green48.png',
#   './dataset/cropped/eva-green\\eva-green49.png',
#   './dataset/cropped/eva-green\\eva-green5.png',
#   './dataset/cropped/eva-green\\eva-green50.png',
#   './dataset/cropped/eva-green\\eva-green51.png',
#   './dataset/cropped/eva-green\\eva-green52.png',
#   './dataset/cropped/eva-green\\eva-green53.png',
#   './dataset/cropped/eva-green\\eva-green54.png',
#   './dataset/cropped/eva-green\\eva-green55.png',
#   './dataset/cropped/eva-green\\eva-green56.png',
#   './dataset/cropped/eva-green\\eva-green57.png',
#   './dataset/cropped/eva-green\\eva-green58.png',
#   './dataset/cropped/eva-green\\eva-green59.png',
#   './dataset/cropped/eva-green\\eva-green6.png',
#   './dataset/cropped/eva-green\\eva-green60.png',
#   './dataset/cropped/eva-green\\eva-green61.png',
#   './dataset/cropped/eva-green\\eva-green62.png',
#   './dataset/cropped/eva-green\\eva-green63.png',
#   './dataset/cropped/eva-green\\eva-green64.png',
#   './dataset/cropped/eva-green\\eva-green65.png',
#   './dataset/cropped/eva-green\\eva-green66.png',
#   './dataset/cropped/eva-green\\eva-green67.png',
#   './dataset/cropped/eva-green\\eva-green68.png',
#   './dataset/cropped/eva-green\\eva-green69.png',
#   './dataset/cropped/eva-green\\eva-green7.png',
#   './dataset/cropped/eva-green\\eva-green70.png',
#   './dataset/cropped/eva-green\\eva-green71.png',
#   './dataset/cropped/eva-green\\eva-green73.png',
#   './dataset/cropped/eva-green\\eva-green74.png',
#   './dataset/cropped/eva-green\\eva-green76.png',
#   './dataset/cropped/eva-green\\eva-green77.png',
#   './dataset/cropped/eva-green\\eva-green78.png',
#   './dataset/cropped/eva-green\\eva-green79.png',
#   './dataset/cropped/eva-green\\eva-green8.png',
#   './dataset/cropped/eva-green\\eva-green80.png',
#   './dataset/cropped/eva-green\\eva-green81.png',
#   './dataset/cropped/eva-green\\eva-green82.png',
#   './dataset/cropped/eva-green\\eva-green83.png',
#   './dataset/cropped/eva-green\\eva-green84.png',
#   './dataset/cropped/eva-green\\eva-green85.png',
#   './dataset/cropped/eva-green\\eva-green87.png',
#   './dataset/cropped/eva-green\\eva-green88.png',
#   './dataset/cropped/eva-green\\eva-green89.png',
#   './dataset/cropped/eva-green\\eva-green90.png',
#   './dataset/cropped/eva-green\\eva-green91.png',
#   './dataset/cropped/eva-green\\eva-green92.png',
#   './dataset/cropped/eva-green\\eva-green93.png',
#   './dataset/cropped/eva-green\\eva-green94.png',
#   './dataset/cropped/eva-green\\eva-green95.png',
#   './dataset/cropped/eva-green\\eva-green96.png',
#   './dataset/cropped/eva-green\\eva-green97.png',
#   './dataset/cropped/eva-green\\eva-green98.png',
#   './dataset/cropped/eva-green\\eva-green99.png'],
#  'husnain': ['./dataset/cropped/husnain\\husnain100.png',
#   './dataset/cropped/husnain\\husnain102.png',
#   './dataset/cropped/husnain\\husnain105.png',
#   './dataset/cropped/husnain\\husnain106.png',
#   './dataset/cropped/husnain\\husnain107.png',
#   './dataset/cropped/husnain\\husnain109.png',
#   './dataset/cropped/husnain\\husnain11.png',
#   './dataset/cropped/husnain\\husnain110.png',
#   './dataset/cropped/husnain\\husnain112.png',
#   './dataset/cropped/husnain\\husnain114.png',
#   './dataset/cropped/husnain\\husnain121.png',
#   './dataset/cropped/husnain\\husnain122.png',
#   './dataset/cropped/husnain\\husnain123.png',
#   './dataset/cropped/husnain\\husnain14.png',
#   './dataset/cropped/husnain\\husnain15.png',
#   './dataset/cropped/husnain\\husnain17.png',
#   './dataset/cropped/husnain\\husnain2.png',
#   './dataset/cropped/husnain\\husnain21.png',
#   './dataset/cropped/husnain\\husnain22.png',
#   './dataset/cropped/husnain\\husnain23.png',
#   './dataset/cropped/husnain\\husnain24.png',
#   './dataset/cropped/husnain\\husnain25.png',
#   './dataset/cropped/husnain\\husnain29.png',
#   './dataset/cropped/husnain\\husnain3.png',
#   './dataset/cropped/husnain\\husnain30.png',
#   './dataset/cropped/husnain\\husnain35.png',
#   './dataset/cropped/husnain\\husnain37.png',
#   './dataset/cropped/husnain\\husnain38.png',
#   './dataset/cropped/husnain\\husnain39.png',
#   './dataset/cropped/husnain\\husnain41.png',
#   './dataset/cropped/husnain\\husnain42.png',
#   './dataset/cropped/husnain\\husnain46.png',
#   './dataset/cropped/husnain\\husnain48.png',
#   './dataset/cropped/husnain\\husnain49.png',
#   './dataset/cropped/husnain\\husnain50.png',
#   './dataset/cropped/husnain\\husnain52.png',
#   './dataset/cropped/husnain\\husnain54.png',
#   './dataset/cropped/husnain\\husnain55.png',
#   './dataset/cropped/husnain\\husnain56.png',
#   './dataset/cropped/husnain\\husnain58.png',
#   './dataset/cropped/husnain\\husnain59.png',
#   './dataset/cropped/husnain\\husnain6.png',
#   './dataset/cropped/husnain\\husnain60.png',
#   './dataset/cropped/husnain\\husnain62.png',
#   './dataset/cropped/husnain\\husnain63.png',
#   './dataset/cropped/husnain\\husnain64.png',
#   './dataset/cropped/husnain\\husnain66.png',
#   './dataset/cropped/husnain\\husnain69.png',
#   './dataset/cropped/husnain\\husnain7.png',
#   './dataset/cropped/husnain\\husnain70.png',
#   './dataset/cropped/husnain\\husnain72.png',
#   './dataset/cropped/husnain\\husnain73.png',
#   './dataset/cropped/husnain\\husnain75.png',
#   './dataset/cropped/husnain\\husnain76.png',
#   './dataset/cropped/husnain\\husnain77.png',
#   './dataset/cropped/husnain\\husnain78.png',
#   './dataset/cropped/husnain\\husnain8.png',
#   './dataset/cropped/husnain\\husnain80.png',
#   './dataset/cropped/husnain\\husnain82.png',
#   './dataset/cropped/husnain\\husnain83.png',
#   './dataset/cropped/husnain\\husnain84.png',
#   './dataset/cropped/husnain\\husnain85.png',
#   './dataset/cropped/husnain\\husnain86.png',
#   './dataset/cropped/husnain\\husnain87.png',
#   './dataset/cropped/husnain\\husnain88.png',
#   './dataset/cropped/husnain\\husnain89.png',
#   './dataset/cropped/husnain\\husnain9.png',
#   './dataset/cropped/husnain\\husnain90.png',
#   './dataset/cropped/husnain\\husnain91.png',
#   './dataset/cropped/husnain\\husnain94.png',
#   './dataset/cropped/husnain\\husnain96.png'],
#  'ronaldo': ['./dataset/cropped/ronaldo\\ronaldo1.png',
#   './dataset/cropped/ronaldo\\ronaldo11.png',
#   './dataset/cropped/ronaldo\\ronaldo12.png',
#   './dataset/cropped/ronaldo\\ronaldo13.png',
#   './dataset/cropped/ronaldo\\ronaldo14.png',
#   './dataset/cropped/ronaldo\\ronaldo15.png',
#   './dataset/cropped/ronaldo\\ronaldo16.png',
#   './dataset/cropped/ronaldo\\ronaldo17.png',
#   './dataset/cropped/ronaldo\\ronaldo18.png',
#   './dataset/cropped/ronaldo\\ronaldo2.png',
#   './dataset/cropped/ronaldo\\ronaldo20.png',
#   './dataset/cropped/ronaldo\\ronaldo21.png',
#   './dataset/cropped/ronaldo\\ronaldo22.png',
#   './dataset/cropped/ronaldo\\ronaldo24.png',
#   './dataset/cropped/ronaldo\\ronaldo25.png',
#   './dataset/cropped/ronaldo\\ronaldo28.png',
#   './dataset/cropped/ronaldo\\ronaldo29.png',
#   './dataset/cropped/ronaldo\\ronaldo3.png',
#   './dataset/cropped/ronaldo\\ronaldo30.png',
#   './dataset/cropped/ronaldo\\ronaldo31.png',
#   './dataset/cropped/ronaldo\\ronaldo32.png',
#   './dataset/cropped/ronaldo\\ronaldo4.png',
#   './dataset/cropped/ronaldo\\ronaldo5.png',
#   './dataset/cropped/ronaldo\\ronaldo6.png',
#   './dataset/cropped/ronaldo\\ronaldo7.png',
#   './dataset/cropped/ronaldo\\ronaldo8.png',
#   './dataset/cropped/ronaldo\\ronaldo9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'alexandra-daddario': 0, 'eva-green': 1, 'husnain': 2, 'ronaldo': 3}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 21],
#        [ 36],
#        [ 31],
#        ...,
#        [148],
#        [177],
#        [164]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (374, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8297872340425532

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85        44
#            1       0.81      0.84      0.83        31
#            2       0.75      1.00      0.86        12
#            3       1.00      0.43      0.60         7
#
#     accuracy                           0.83        94
#    macro avg       0.86      0.78      0.78        94
# weighted avg       0.84      0.83      0.82        94

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\DELL\.pyenv\pyenv-win\versions\3.12.0\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#                  model  best_score  \
# 0                  svm    0.882143
# 1        random_forest    0.789286
# 2  logistic_regression    0.878571
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, multi_class='auto',
#                                      solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.851063829787234

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7021276595744681

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8404255319148937

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[38,  3,  3,  0],
#        [ 5, 25,  1,  0],
#        [ 0,  0, 12,  0],
#        [ 2,  0,  0,  5]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'alexandra-daddario': 0, 'eva-green': 1, 'husnain': 2, 'ronaldo': 3}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\dell\.pyenv\pyenv-win\versions\3.12.0\lib\site-packages (1.4.2)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
